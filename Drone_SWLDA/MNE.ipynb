# %%
import mne
from mne.externals.pymatreader import read_mat

# fname = '/Users/hyuns/Desktop/공학프로젝트기획/Signal Processing Study/s43000.mat'
fname = '/Users/hyuns/Desktop/HGU/2020-2/Capstone/Drone Project/EEGData/VR300_Data/0729/hs/Online/1_2.mat'

mat_data = read_mat(fname)

# %%
mat_data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: \xbc\xf6 7 29 12:38:15 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'stims': array([[ 6.67042436,  1.        ,  0.        ],
#         [ 6.87590325,  5.        ,  0.        ],
#         [ 7.06086181,  7.        ,  0.        ],
#         [ 7.27801465,  2.        ,  0.        ],
#         [ 7.47101205,  3.        ,  0.        ],
#         [ 7.67657898,  4.        ,  0.        ],
#         [ 7.87201381,  6.        ,  0.        ],
#         [ 8.05348786,  5.        ,  0.        ],
#         [ 8.25613967,  6.        ,  0.        ],
#         [ 8.4618044 ,  3.        ,  0.        ],
#         [ 8.66672464,  2.        ,  0.        ],
#         [ 8.8677608 ,  4.        ,  0.        ],
#         [ 9.05676394,  7.        ,  0.        ],
#         [ 9.25882772,  1.        ,  0.        ],
#         [ 9.46507937,  7.        ,  0.        ],
#         [ 9.66761468,  4.        ,  0.        ],
# ...

# %%
info = mne.create_info(ch_names=7, sfreq=300, ch_types='eeg')

# %%
mat_data['raw'] = mat_data.pop('raw').transpose()

# %%
raw = io.RawArray(mat_data['raw'], info=info)
# Out:
# Creating RawArray with float64 data, n_channels=7, n_times=10720
#     Range : 0 ... 10719 =      0.000 ...    35.730 secs
# Ready.

# %%
# Out:
# <RawArray | 7 x 10720 (35.7 s), ~605 kB, data loaded>

# %%
info['chs']
# Out:
# [{'loc': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 2 (FIFFV_EEG_CH),
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 4 (FIFFV_COORD_HEAD),
#   'ch_name': '0',
#   'scanno': 1,
#   'logno': 1},
#  {'loc': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 2 (FIFFV_EEG_CH),
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 4 (FIFFV_COORD_HEAD),
#   'ch_name': '1',
#   'scanno': 2,
#   'logno': 2},
#  {'loc': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 2 (FIFFV_EEG_CH),
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 4 (FIFFV_COORD_HEAD),
#   'ch_name': '2',
#   'scanno': 3,
#   'logno': 3},
# ...
